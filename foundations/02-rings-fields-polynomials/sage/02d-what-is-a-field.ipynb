# %% [markdown]
# # What Is a Field?
#
# **Module 02** | 02-rings-fields-polynomials
#
# *Every element invertible, Z_p is field iff p prime*

# %% [markdown]
# ## Objectives
#
# By the end of this notebook you will be able to:
#
# 1. Understand the core ideas behind **what is a field?**.
# 2. Explore these concepts interactively using SageMath.
# 3. Build intuition through hands-on computation and visualization.

# %% [markdown]
# ## Prerequisites
#
# - Completion of [Polynomial Rings](02c-polynomial-rings.ipynb).
# - Concepts and notation introduced in the previous notebook.

# %% [markdown]
# ## Field Definition

# %%
# A field is a commutative ring where every nonzero element is a unit
F = GF(7)
print('Is field?', F.is_field())

# %% [markdown]
# ## Z_p Is a Field When p Is Prime

# %%
# Check: Zmod(p) is a field iff p is prime
for n in range(2, 16):
    R = Zmod(n)
    print(f'Z/{n}Z is field: {R.is_field()}, {n} is prime: {is_prime(n)}')

# %% [markdown]
# ## Inverses in a Prime Field

# %%
# Every nonzero element of GF(p) has a multiplicative inverse
F = GF(7)
for a in F:
    if a != 0:
        print(f'{a}^(-1) = {a^(-1)}')

# %% [markdown]
# ## Exercises
#
# Try these on your own before moving on:
#
# 1. **Exercise 1:** *(TODO: add exercise)*
# 2. **Exercise 2:** *(TODO: add exercise)*
# 3. **Exercise 3:** *(TODO: add exercise)*

# %% [markdown]
# ## Summary
#
# In this notebook we explored **what is a field?**.  Key takeaways:
#
# - *(TODO: summarize key point 1)*
# - *(TODO: summarize key point 2)*
# - *(TODO: summarize key point 3)*
#
# **Next:** [Polynomial Division and Irreducibility](02e-polynomial-division-irreducibility.ipynb)
