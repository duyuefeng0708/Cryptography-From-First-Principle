# %% [markdown]
# # Integers Mod n as a Ring
#
# **Module 02** | 02-rings-fields-polynomials
#
# *Zmod(12), zero divisors, units*

# %% [markdown]
# ## Objectives
#
# By the end of this notebook you will be able to:
#
# 1. Understand the core ideas behind **integers mod n as a ring**.
# 2. Explore these concepts interactively using SageMath.
# 3. Build intuition through hands-on computation and visualization.

# %% [markdown]
# ## Prerequisites
#
# - Completion of [What Is a Ring?](02a-what-is-a-ring.ipynb).
# - Concepts and notation introduced in the previous notebook.

# %% [markdown]
# ## Building Z/nZ

# %%
# Create Z/12Z and inspect basic properties
R = Zmod(12)
print('Order:', R.order())
print('Is field?', R.is_field())

# %% [markdown]
# ## Zero Divisors

# %%
# Find zero divisors in Z/12Z: a*b == 0 with a,b != 0
R = Zmod(12)
for a in R:
    for b in R:
        if a != 0 and b != 0 and a*b == 0:
            print(f'{a} * {b} = 0')

# %% [markdown]
# ## Units and the Unit Group

# %%
# The units of Z/12Z form a group under multiplication
R = Zmod(12)
units = [x for x in R if gcd(ZZ(x), 12) == 1]
print('Units:', units)

# %% [markdown]
# ## Exercises
#
# Try these on your own before moving on:
#
# 1. **Exercise 1:** *(TODO: add exercise)*
# 2. **Exercise 2:** *(TODO: add exercise)*
# 3. **Exercise 3:** *(TODO: add exercise)*

# %% [markdown]
# ## Summary
#
# In this notebook we explored **integers mod n as a ring**.  Key takeaways:
#
# - *(TODO: summarize key point 1)*
# - *(TODO: summarize key point 2)*
# - *(TODO: summarize key point 3)*
#
# **Next:** [Polynomial Rings](02c-polynomial-rings.ipynb)
