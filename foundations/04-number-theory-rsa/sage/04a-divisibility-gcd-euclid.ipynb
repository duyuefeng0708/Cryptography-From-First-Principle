# %% [markdown]
# # Divisibility and the Euclidean Algorithm
#
# **Module 04** | 04-number-theory-rsa
#
# *gcd(), step-by-step Euclid*

# %% [markdown]
# ## Objectives
#
# By the end of this notebook you will be able to:
#
# 1. Understand the core ideas behind **divisibility and the euclidean algorithm**.
# 2. Explore these concepts interactively using SageMath.
# 3. Build intuition through hands-on computation and visualization.

# %% [markdown]
# ## Prerequisites
#
# - Basic familiarity with Python syntax.
# - A working SageMath installation (or access to CoCalc/SageMathCell).

# %% [markdown]
# ## Divisibility

# %%
# Test divisibility and list divisors
n = 60
print('Divisors of', n, ':', divisors(n))

# %% [markdown]
# ## The Euclidean Algorithm

# %%
# Step-by-step Euclidean algorithm
a, b = 252, 105
while b != 0:
    print(f'{a} = {a//b}*{b} + {a%b}')
    a, b = b, a % b
print('GCD:', a)

# %% [markdown]
# ## Using SageMath's gcd()

# %%
# Verify with SageMath's built-in
print(gcd(252, 105))
print(gcd(48, 18))

# %% [markdown]
# ## Exercises
#
# Try these on your own before moving on:
#
# 1. **Exercise 1:** *(TODO: add exercise)*
# 2. **Exercise 2:** *(TODO: add exercise)*
# 3. **Exercise 3:** *(TODO: add exercise)*

# %% [markdown]
# ## Summary
#
# In this notebook we explored **divisibility and the euclidean algorithm**.  Key takeaways:
#
# - *(TODO: summarize key point 1)*
# - *(TODO: summarize key point 2)*
# - *(TODO: summarize key point 3)*
#
# **Next:** [The Extended Euclidean Algorithm](04b-extended-euclidean-algorithm.ipynb)
