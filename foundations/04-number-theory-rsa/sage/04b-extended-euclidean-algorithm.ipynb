# %% [markdown]
# # The Extended Euclidean Algorithm
#
# **Module 04** | 04-number-theory-rsa
#
# *xgcd(), Bezout, mod inverse*

# %% [markdown]
# ## Objectives
#
# By the end of this notebook you will be able to:
#
# 1. Understand the core ideas behind **the extended euclidean algorithm**.
# 2. Explore these concepts interactively using SageMath.
# 3. Build intuition through hands-on computation and visualization.

# %% [markdown]
# ## Prerequisites
#
# - Completion of [Divisibility and the Euclidean Algorithm](04a-divisibility-gcd-euclid.ipynb).
# - Concepts and notation introduced in the previous notebook.

# %% [markdown]
# ## Bezout's Identity

# %%
# Find s, t such that gcd(a,b) = s*a + t*b
g, s, t = xgcd(252, 105)
print(f'gcd = {g}, s = {s}, t = {t}')
print(f'Verify: {s}*252 + {t}*105 = {s*252 + t*105}')

# %% [markdown]
# ## Computing Modular Inverses

# %%
# The extended GCD gives us modular inverses
# Find 17^(-1) mod 43
g, s, _ = xgcd(17, 43)
print(f'17^(-1) mod 43 = {s % 43}')

# %% [markdown]
# ## When Does an Inverse Exist?

# %%
# a has an inverse mod n iff gcd(a, n) = 1
n = 15
for a in range(1, n):
    g = gcd(a, n)
    inv = f'{inverse_mod(a, n)}' if g == 1 else 'none'
    print(f'{a}: gcd={g}, inverse={inv}')

# %% [markdown]
# ## Exercises
#
# Try these on your own before moving on:
#
# 1. **Exercise 1:** *(TODO: add exercise)*
# 2. **Exercise 2:** *(TODO: add exercise)*
# 3. **Exercise 3:** *(TODO: add exercise)*

# %% [markdown]
# ## Summary
#
# In this notebook we explored **the extended euclidean algorithm**.  Key takeaways:
#
# - *(TODO: summarize key point 1)*
# - *(TODO: summarize key point 2)*
# - *(TODO: summarize key point 3)*
#
# **Next:** [Euler's Totient and Fermat's Theorem](04c-euler-totient-fermats-theorem.ipynb)
