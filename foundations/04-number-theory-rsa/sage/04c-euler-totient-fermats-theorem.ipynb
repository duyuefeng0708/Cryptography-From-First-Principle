# %% [markdown]
# # Euler's Totient and Fermat's Theorem
#
# **Module 04** | 04-number-theory-rsa
#
# *euler_phi(), power_mod()*

# %% [markdown]
# ## Objectives
#
# By the end of this notebook you will be able to:
#
# 1. Understand the core ideas behind **euler's totient and fermat's theorem**.
# 2. Explore these concepts interactively using SageMath.
# 3. Build intuition through hands-on computation and visualization.

# %% [markdown]
# ## Prerequisites
#
# - Completion of [The Extended Euclidean Algorithm](04b-extended-euclidean-algorithm.ipynb).
# - Concepts and notation introduced in the previous notebook.

# %% [markdown]
# ## Euler's Totient Function

# %%
# phi(n) counts integers 1..n coprime to n
for n in range(2, 21):
    print(f'phi({n}) = {euler_phi(n)}')

# %% [markdown]
# ## Fermat's Little Theorem

# %%
# a^(p-1) = 1 (mod p) for prime p, gcd(a,p)=1
p = 17
for a in range(1, p):
    print(f'{a}^{p-1} mod {p} = {power_mod(a, p-1, p)}')

# %% [markdown]
# ## Euler's Theorem

# %%
# a^phi(n) = 1 (mod n) when gcd(a,n)=1
n = 15
phi_n = euler_phi(n)
for a in range(1, n):
    if gcd(a, n) == 1:
        print(f'{a}^{phi_n} mod {n} = {power_mod(a, phi_n, n)}')

# %% [markdown]
# ## Exercises
#
# Try these on your own before moving on:
#
# 1. **Exercise 1:** *(TODO: add exercise)*
# 2. **Exercise 2:** *(TODO: add exercise)*
# 3. **Exercise 3:** *(TODO: add exercise)*

# %% [markdown]
# ## Summary
#
# In this notebook we explored **euler's totient and fermat's theorem**.  Key takeaways:
#
# - *(TODO: summarize key point 1)*
# - *(TODO: summarize key point 2)*
# - *(TODO: summarize key point 3)*
#
# **Next:** [The Chinese Remainder Theorem](04d-chinese-remainder-theorem.ipynb)
