# %% [markdown]
# # RSA Encryption and Decryption
#
# **Module 04** | 04-number-theory-rsa
#
# *Encrypt/decrypt, textbook RSA limits*

# %% [markdown]
# ## Objectives
#
# By the end of this notebook you will be able to:
#
# 1. Understand the core ideas behind **rsa encryption and decryption**.
# 2. Explore these concepts interactively using SageMath.
# 3. Build intuition through hands-on computation and visualization.

# %% [markdown]
# ## Prerequisites
#
# - Completion of [RSA Key Generation](04e-rsa-key-generation.ipynb).
# - Concepts and notation introduced in the previous notebook.

# %% [markdown]
# ## Textbook RSA Encryption

# %%
# Encrypt: c = m^e mod n
# TODO: set up RSA parameters and encrypt a message

# %% [markdown]
# ## Textbook RSA Decryption

# %%
# Decrypt: m = c^d mod n
# TODO: decrypt and verify we recover the original message

# %% [markdown]
# ## Why Textbook RSA Is Insecure

# %%
# Textbook RSA is deterministic -> same plaintext = same ciphertext
# TODO: demonstrate the lack of semantic security

# %% [markdown]
# ## Exercises
#
# Try these on your own before moving on:
#
# 1. **Exercise 1:** *(TODO: add exercise)*
# 2. **Exercise 2:** *(TODO: add exercise)*
# 3. **Exercise 3:** *(TODO: add exercise)*

# %% [markdown]
# ## Summary
#
# In this notebook we explored **rsa encryption and decryption**.  Key takeaways:
#
# - *(TODO: summarize key point 1)*
# - *(TODO: summarize key point 2)*
# - *(TODO: summarize key point 3)*
