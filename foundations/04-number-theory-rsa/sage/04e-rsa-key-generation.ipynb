# %% [markdown]
# # RSA Key Generation
#
# **Module 04** | 04-number-theory-rsa
#
# *random_prime(), step-by-step keygen*

# %% [markdown]
# ## Objectives
#
# By the end of this notebook you will be able to:
#
# 1. Understand the core ideas behind **rsa key generation**.
# 2. Explore these concepts interactively using SageMath.
# 3. Build intuition through hands-on computation and visualization.

# %% [markdown]
# ## Prerequisites
#
# - Completion of [The Chinese Remainder Theorem](04d-chinese-remainder-theorem.ipynb).
# - Concepts and notation introduced in the previous notebook.

# %% [markdown]
# ## Generating Large Primes

# %%
# Use random_prime() to pick primes of a given size
p = random_prime(2^512)
q = random_prime(2^512)
print(f'p = {p}')
print(f'q = {q}')

# %% [markdown]
# ## Computing the RSA Modulus

# %%
# n = p*q, phi(n) = (p-1)*(q-1)
p = random_prime(2^64)
q = random_prime(2^64)
n = p * q
phi_n = (p-1) * (q-1)
print(f'n = {n}')
print(f'phi(n) = {phi_n}')

# %% [markdown]
# ## Choosing e and Computing d

# %%
# e = 65537 (standard), d = e^(-1) mod phi(n)
e = 65537
# Ensure gcd(e, phi_n) == 1
# d = inverse_mod(e, phi_n)
# TODO: complete keygen and output (n, e) and (n, d)

# %% [markdown]
# ## Exercises
#
# Try these on your own before moving on:
#
# 1. **Exercise 1:** *(TODO: add exercise)*
# 2. **Exercise 2:** *(TODO: add exercise)*
# 3. **Exercise 3:** *(TODO: add exercise)*

# %% [markdown]
# ## Summary
#
# In this notebook we explored **rsa key generation**.  Key takeaways:
#
# - *(TODO: summarize key point 1)*
# - *(TODO: summarize key point 2)*
# - *(TODO: summarize key point 3)*
#
# **Next:** [RSA Encryption and Decryption](04f-rsa-encryption-decryption.ipynb)
