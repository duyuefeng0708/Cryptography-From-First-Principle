# %% [markdown]
# # Modular Arithmetic
#
# **Module 01** | 01-modular-arithmetic-groups
#
# *Congruences, Zmod(n), addition/multiplication tables*

# %% [markdown]
# ## Objectives
#
# By the end of this notebook you will be able to:
#
# 1. Understand the core ideas behind **modular arithmetic**.
# 2. Explore these concepts interactively using SageMath.
# 3. Build intuition through hands-on computation and visualization.

# %% [markdown]
# ## Prerequisites
#
# - Completion of [Integers and Division](01a-integers-and-division.ipynb).
# - Concepts and notation introduced in the previous notebook.

# %% [markdown]
# ## Congruence Classes

# %%
# Create the ring Z/12Z and inspect its elements
R = Zmod(12)
print(list(R))

# %% [markdown]
# ## Addition and Multiplication Tables

# %%
# Build and display the addition table for Z/7Z
R = Zmod(7)
R.addition_table('elements')

# %% [markdown]
# ## Patterns in Multiplication

# %%
# Display the multiplication table and look for zero divisors
R = Zmod(12)
R.multiplication_table('elements')

# %% [markdown]
# ## Exercises
#
# Try these on your own before moving on:
#
# 1. **Exercise 1:** *(TODO: add exercise)*
# 2. **Exercise 2:** *(TODO: add exercise)*
# 3. **Exercise 3:** *(TODO: add exercise)*

# %% [markdown]
# ## Summary
#
# In this notebook we explored **modular arithmetic**.  Key takeaways:
#
# - *(TODO: summarize key point 1)*
# - *(TODO: summarize key point 2)*
# - *(TODO: summarize key point 3)*
#
# **Next:** [Groups: A First Look](01c-groups-first-look.ipynb)
