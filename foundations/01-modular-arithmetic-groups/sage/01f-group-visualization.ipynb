# %% [markdown]
# # Visualizing Group Structure
#
# **Module 01** | 01-modular-arithmetic-groups
#
# *Cayley graphs, subgroup lattices*

# %% [markdown]
# ## Objectives
#
# By the end of this notebook you will be able to:
#
# 1. Understand the core ideas behind **visualizing group structure**.
# 2. Explore these concepts interactively using SageMath.
# 3. Build intuition through hands-on computation and visualization.

# %% [markdown]
# ## Prerequisites
#
# - Completion of [Subgroups and Lagrange's Theorem](01e-subgroups-lagrange.ipynb).
# - Concepts and notation introduced in the previous notebook.

# %% [markdown]
# ## Cayley Graphs

# %%
# Visualize Z/6Z with generator 1
G = Zmod(6)
# TODO: build and plot Cayley graph

# %% [markdown]
# ## Subgroup Lattice Diagrams

# %%
# Draw the subgroup lattice of Z/12Z
# TODO: use SageMath poset for subgroup lattice

# %% [markdown]
# ## Color-Coded Multiplication Tables

# %%
# Create a color-coded multiplication table
# TODO: matplotlib heatmap of Z/7Z multiplication

# %% [markdown]
# ## Exercises
#
# Try these on your own before moving on:
#
# 1. **Exercise 1:** *(TODO: add exercise)*
# 2. **Exercise 2:** *(TODO: add exercise)*
# 3. **Exercise 3:** *(TODO: add exercise)*

# %% [markdown]
# ## Summary
#
# In this notebook we explored **visualizing group structure**.  Key takeaways:
#
# - *(TODO: summarize key point 1)*
# - *(TODO: summarize key point 2)*
# - *(TODO: summarize key point 3)*
