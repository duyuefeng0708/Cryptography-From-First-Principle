# %% [markdown]
# # Point Addition: The Geometry
#
# **Module 06** | 06-elliptic-curves
#
# *Chord-and-tangent, point at infinity*

# %% [markdown]
# ## Objectives
#
# By the end of this notebook you will be able to:
#
# 1. Understand the core ideas behind **point addition: the geometry**.
# 2. Explore these concepts interactively using SageMath.
# 3. Build intuition through hands-on computation and visualization.

# %% [markdown]
# ## Prerequisites
#
# - Completion of [Elliptic Curves over the Reals](06a-curves-over-reals.ipynb).
# - Concepts and notation introduced in the previous notebook.

# %% [markdown]
# ## The Chord-and-Tangent Rule

# %%
# To add P + Q: draw line through P and Q, find third intersection, reflect
E = EllipticCurve(QQ, [-1, 1])
P = E(0, 1)
Q = E(1, 1)
print(f'P + Q = {P + Q}')

# %% [markdown]
# ## The Point at Infinity

# %%
# The identity element: O (point at infinity)
E = EllipticCurve(QQ, [-1, 1])
P = E(0, 1)
O = E(0)  # point at infinity
print(f'P + O = {P + O}')

# %% [markdown]
# ## Point Doubling

# %%
# When P = Q, use the tangent line
E = EllipticCurve(QQ, [-1, 1])
P = E(0, 1)
print(f'2*P = {2*P}')

# %% [markdown]
# ## Exercises
#
# Try these on your own before moving on:
#
# 1. **Exercise 1:** *(TODO: add exercise)*
# 2. **Exercise 2:** *(TODO: add exercise)*
# 3. **Exercise 3:** *(TODO: add exercise)*

# %% [markdown]
# ## Summary
#
# In this notebook we explored **point addition: the geometry**.  Key takeaways:
#
# - *(TODO: summarize key point 1)*
# - *(TODO: summarize key point 2)*
# - *(TODO: summarize key point 3)*
#
# **Next:** [Curves over Finite Fields](06c-curves-over-finite-fields.ipynb)
