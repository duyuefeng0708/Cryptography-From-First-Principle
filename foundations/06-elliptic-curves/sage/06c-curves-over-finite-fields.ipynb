# %% [markdown]
# # Curves over Finite Fields
#
# **Module 06** | 06-elliptic-curves
#
# *EllipticCurve(GF(p),[a,b]), points()*

# %% [markdown]
# ## Objectives
#
# By the end of this notebook you will be able to:
#
# 1. Understand the core ideas behind **curves over finite fields**.
# 2. Explore these concepts interactively using SageMath.
# 3. Build intuition through hands-on computation and visualization.

# %% [markdown]
# ## Prerequisites
#
# - Completion of [Point Addition: The Geometry](06b-point-addition-geometry.ipynb).
# - Concepts and notation introduced in the previous notebook.

# %% [markdown]
# ## Defining a Curve over GF(p)

# %%
# Create an elliptic curve over a prime field
p = 23
E = EllipticCurve(GF(p), [1, 1])
print(E)

# %% [markdown]
# ## Listing All Points

# %%
# Enumerate every point on the curve
p = 23
E = EllipticCurve(GF(p), [1, 1])
pts = E.points()
print(f'{len(pts)} points (including O)')
for P in pts:
    print(P)

# %% [markdown]
# ## Point Arithmetic over GF(p)

# %%
# Addition and scalar multiplication work the same way
p = 23
E = EllipticCurve(GF(p), [1, 1])
P = E.random_point()
Q = E.random_point()
print(f'P = {P}')
print(f'Q = {Q}')
print(f'P + Q = {P + Q}')

# %% [markdown]
# ## Exercises
#
# Try these on your own before moving on:
#
# 1. **Exercise 1:** *(TODO: add exercise)*
# 2. **Exercise 2:** *(TODO: add exercise)*
# 3. **Exercise 3:** *(TODO: add exercise)*

# %% [markdown]
# ## Summary
#
# In this notebook we explored **curves over finite fields**.  Key takeaways:
#
# - *(TODO: summarize key point 1)*
# - *(TODO: summarize key point 2)*
# - *(TODO: summarize key point 3)*
#
# **Next:** [Group Structure and Order](06d-group-structure-and-order.ipynb)
