# %% [markdown]
# # Extension Fields GF(2^n)
#
# **Module 03** | 03-galois-fields-aes
#
# *Building GF(2^n) from polynomial quotient rings*

# %% [markdown]
# ## Objectives
#
# By the end of this notebook you will be able to:
#
# 1. Understand the core ideas behind **extension fields gf(2^n)**.
# 2. Explore these concepts interactively using SageMath.
# 3. Build intuition through hands-on computation and visualization.

# %% [markdown]
# ## Prerequisites
#
# - Completion of [The Binary Field GF(2)](03a-binary-fields-gf2.ipynb).
# - Concepts and notation introduced in the previous notebook.

# %% [markdown]
# ## From GF(2) to GF(2^n)

# %%
# Build GF(2^4) using an irreducible polynomial
F.<a> = GF(2^4)
print(F)
print('Modulus:', F.modulus())

# %% [markdown]
# ## Elements as Polynomials

# %%
# Each element of GF(2^n) is a polynomial of degree < n
F.<a> = GF(2^4)
for x in F:
    print(x, '->', x.polynomial())

# %% [markdown]
# ## Arithmetic in GF(2^n)

# %%
# Add and multiply elements
F.<a> = GF(2^4)
x = a^3 + a + 1
y = a^2 + a
print(f'{x} + {y} = {x+y}')
print(f'{x} * {y} = {x*y}')

# %% [markdown]
# ## Exercises
#
# Try these on your own before moving on:
#
# 1. **Exercise 1:** *(TODO: add exercise)*
# 2. **Exercise 2:** *(TODO: add exercise)*
# 3. **Exercise 3:** *(TODO: add exercise)*

# %% [markdown]
# ## Summary
#
# In this notebook we explored **extension fields gf(2^n)**.  Key takeaways:
#
# - *(TODO: summarize key point 1)*
# - *(TODO: summarize key point 2)*
# - *(TODO: summarize key point 3)*
#
# **Next:** [Arithmetic in GF(256)](03c-gf256-arithmetic.ipynb)
