# %% [markdown]
# # A Full AES Round
#
# **Module 03** | 03-galois-fields-aes
#
# *SubBytes + ShiftRows + MixColumns + AddRoundKey*

# %% [markdown]
# ## Objectives
#
# By the end of this notebook you will be able to:
#
# 1. Understand the core ideas behind **a full aes round**.
# 2. Explore these concepts interactively using SageMath.
# 3. Build intuition through hands-on computation and visualization.

# %% [markdown]
# ## Prerequisites
#
# - Completion of [AES MixColumns as Field Operations](03e-aes-mixcolumns-as-field-ops.ipynb).
# - Concepts and notation introduced in the previous notebook.

# %% [markdown]
# ## SubBytes: Byte Substitution

# %%
# Apply the S-Box to every byte of the state
# TODO: apply S-Box lookup to 4x4 state matrix

# %% [markdown]
# ## ShiftRows and MixColumns

# %%
# ShiftRows: cyclic left shift of each row
# MixColumns: matrix multiply each column
# TODO: implement ShiftRows and MixColumns

# %% [markdown]
# ## AddRoundKey and Full Round

# %%
# XOR the state with the round key
# TODO: combine all four operations into one AES round

# %% [markdown]
# ## Exercises
#
# Try these on your own before moving on:
#
# 1. **Exercise 1:** *(TODO: add exercise)*
# 2. **Exercise 2:** *(TODO: add exercise)*
# 3. **Exercise 3:** *(TODO: add exercise)*

# %% [markdown]
# ## Summary
#
# In this notebook we explored **a full aes round**.  Key takeaways:
#
# - *(TODO: summarize key point 1)*
# - *(TODO: summarize key point 2)*
# - *(TODO: summarize key point 3)*
