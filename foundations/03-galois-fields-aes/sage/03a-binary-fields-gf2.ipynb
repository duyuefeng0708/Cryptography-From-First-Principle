# %% [markdown]
# # The Binary Field GF(2)
#
# **Module 03** | 03-galois-fields-aes
#
# *XOR as addition, AND as multiplication*

# %% [markdown]
# ## Objectives
#
# By the end of this notebook you will be able to:
#
# 1. Understand the core ideas behind **the binary field gf(2)**.
# 2. Explore these concepts interactively using SageMath.
# 3. Build intuition through hands-on computation and visualization.

# %% [markdown]
# ## Prerequisites
#
# - Basic familiarity with Python syntax.
# - A working SageMath installation (or access to CoCalc/SageMathCell).

# %% [markdown]
# ## GF(2): The Smallest Field

# %%
# GF(2) has only 0 and 1
F = GF(2)
print('Elements:', list(F))

# %% [markdown]
# ## XOR Is Addition

# %%
# Addition in GF(2) is XOR
F = GF(2)
for a in F:
    for b in F:
        print(f'{a} + {b} = {a+b}')

# %% [markdown]
# ## AND Is Multiplication

# %%
# Multiplication in GF(2) is AND
F = GF(2)
for a in F:
    for b in F:
        print(f'{a} * {b} = {a*b}')

# %% [markdown]
# ## Exercises
#
# Try these on your own before moving on:
#
# 1. **Exercise 1:** *(TODO: add exercise)*
# 2. **Exercise 2:** *(TODO: add exercise)*
# 3. **Exercise 3:** *(TODO: add exercise)*

# %% [markdown]
# ## Summary
#
# In this notebook we explored **the binary field gf(2)**.  Key takeaways:
#
# - *(TODO: summarize key point 1)*
# - *(TODO: summarize key point 2)*
# - *(TODO: summarize key point 3)*
#
# **Next:** [Extension Fields GF(2^n)](03b-extension-fields-gf2n.ipynb)
