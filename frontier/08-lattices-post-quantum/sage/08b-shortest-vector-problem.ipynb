# %% [markdown]
# # The Shortest Vector Problem
#
# **Module 08** | 08-lattices-post-quantum
#
# *SVP, good vs bad bases*

# %% [markdown]
# ## Objectives
#
# By the end of this notebook you will be able to:
#
# 1. Understand the core ideas behind **the shortest vector problem**.
# 2. Explore these concepts interactively using SageMath.
# 3. Build intuition through hands-on computation and visualization.

# %% [markdown]
# ## Prerequisites
#
# - Completion of [Lattices and Bases](08a-lattices-and-bases.ipynb).
# - Concepts and notation introduced in the previous notebook.

# %% [markdown]
# ## SVP Definition

# %%
# Find the shortest nonzero vector in a lattice
# This is NP-hard in general
B = matrix(ZZ, [[1, 0], [0, 1]])
L = B.LLL()
print('Reduced basis:\n', L)

# %% [markdown]
# ## Good Bases vs Bad Bases

# %%
# A 'good' basis has short, nearly orthogonal vectors
# A 'bad' basis has long, nearly parallel vectors
# TODO: compare a good and bad basis for the same lattice

# %% [markdown]
# ## Approximating SVP

# %%
# LLL gives a vector within 2^(n/2) of the shortest
B = matrix(ZZ, [[1, 0, 3], [0, 1, 5], [0, 0, 7]])
L = B.LLL()
print('LLL-reduced basis:\n', L)
print('Short vector:', L[0])

# %% [markdown]
# ## Exercises
#
# Try these on your own before moving on:
#
# 1. **Exercise 1:** *(TODO: add exercise)*
# 2. **Exercise 2:** *(TODO: add exercise)*
# 3. **Exercise 3:** *(TODO: add exercise)*

# %% [markdown]
# ## Summary
#
# In this notebook we explored **the shortest vector problem**.  Key takeaways:
#
# - *(TODO: summarize key point 1)*
# - *(TODO: summarize key point 2)*
# - *(TODO: summarize key point 3)*
#
# **Next:** [The LLL Algorithm](08c-lll-algorithm.ipynb)
