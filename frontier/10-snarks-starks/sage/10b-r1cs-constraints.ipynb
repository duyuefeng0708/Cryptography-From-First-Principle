# %% [markdown]
# # R1CS Constraints
#
# **Module 10** | 10-snarks-starks
#
# *A*s . B*s = C*s, flattening, witness*

# %% [markdown]
# ## Objectives
#
# By the end of this notebook you will be able to:
#
# 1. Understand the core ideas behind **r1cs constraints**.
# 2. Explore these concepts interactively using SageMath.
# 3. Build intuition through hands-on computation and visualization.

# %% [markdown]
# ## Prerequisites
#
# - Completion of [Arithmetic Circuits](10a-arithmetic-circuits.ipynb).
# - Concepts and notation introduced in the previous notebook.

# %% [markdown]
# ## Rank-1 Constraint System

# %%
# Each gate becomes a constraint: (A_i . s) * (B_i . s) = (C_i . s)
# s = (1, x, w1, w2, ..., output) is the witness vector
# TODO: build R1CS matrices for x^3 + x + 5

# %% [markdown]
# ## The Witness

# %%
# The witness includes all intermediate wire values
# s = [1, x, x*x, x*x*x, x*x*x+x, x*x*x+x+5]
# TODO: construct witness for a given input

# %% [markdown]
# ## Checking Satisfiability

# %%
# Verify that A*s . B*s == C*s for all constraints
# TODO: programmatically verify the R1CS

# %% [markdown]
# ## Exercises
#
# Try these on your own before moving on:
#
# 1. **Exercise 1:** *(TODO: add exercise)*
# 2. **Exercise 2:** *(TODO: add exercise)*
# 3. **Exercise 3:** *(TODO: add exercise)*

# %% [markdown]
# ## Summary
#
# In this notebook we explored **r1cs constraints**.  Key takeaways:
#
# - *(TODO: summarize key point 1)*
# - *(TODO: summarize key point 2)*
# - *(TODO: summarize key point 3)*
#
# **Next:** [QAP Construction](10c-qap-construction.ipynb)
