# %% [markdown]
# # Arithmetic Circuits
#
# **Module 10** | 10-snarks-starks
#
# *Addition/multiplication gates, wire values*

# %% [markdown]
# ## Objectives
#
# By the end of this notebook you will be able to:
#
# 1. Understand the core ideas behind **arithmetic circuits**.
# 2. Explore these concepts interactively using SageMath.
# 3. Build intuition through hands-on computation and visualization.

# %% [markdown]
# ## Prerequisites
#
# - Basic familiarity with Python syntax.
# - A working SageMath installation (or access to CoCalc/SageMathCell).

# %% [markdown]
# ## What Is an Arithmetic Circuit?

# %%
# A DAG of addition and multiplication gates over a field
# Inputs -> gates -> output
# TODO: define a simple circuit: f(x) = x^3 + x + 5

# %% [markdown]
# ## Wire Values and Evaluation

# %%
# Assign values to input wires, propagate through gates
# TODO: trace wire values for f(3) = 27 + 3 + 5 = 35

# %% [markdown]
# ## Flattening to Gates

# %%
# Any computation can be flattened to a sequence of gates
# x^3 + x + 5:
#   w1 = x * x
#   w2 = w1 * x
#   w3 = w2 + x
#   w4 = w3 + 5
# TODO: implement flattening

# %% [markdown]
# ## Exercises
#
# Try these on your own before moving on:
#
# 1. **Exercise 1:** *(TODO: add exercise)*
# 2. **Exercise 2:** *(TODO: add exercise)*
# 3. **Exercise 3:** *(TODO: add exercise)*

# %% [markdown]
# ## Summary
#
# In this notebook we explored **arithmetic circuits**.  Key takeaways:
#
# - *(TODO: summarize key point 1)*
# - *(TODO: summarize key point 2)*
# - *(TODO: summarize key point 3)*
#
# **Next:** [R1CS Constraints](10b-r1cs-constraints.ipynb)
